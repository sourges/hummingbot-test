# %%
from hummingbot_api_client import HummingbotAPIClient

client = HummingbotAPIClient(base_url='http://localhost:8000')
await client.init()
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7f9b7ed8a960>

# %%
await client.connectors.list_connectors()
# Out:
# ['bitmart_perpetual',
#  'dydx_v4_perpetual',
#  'bybit_perpetual',
#  'bybit_perpetual_testnet',
#  'binance_perpetual',
#  'binance_perpetual_testnet',
#  'gate_io_perpetual',
#  'hyperliquid_perpetual',
#  'hyperliquid_perpetual_testnet',
#  'okx_perpetual',
#  'injective_v2_perpetual',
#  'derive_perpetual',
#  'derive_perpetual_testnet',
#  'kucoin_perpetual',
#  'bitget_perpetual',
#  'bitrue',
#  'kucoin',
#  'kucoin_hft',
#  'bitstamp',
#  'dexalot',
#  'dexalot_testnet',
#  'bybit',
#  'bybit_testnet',
#  'binance',
#  'binance_us',
#  'bitmart',
#  'bitget',
#  'cube',
#  'xrpl',
#  'mexc',
#  'vertex',
#  'vertex_testnet',
#  'htx',
#  'kraken',
#  'ascend_ex',
#  'derive',
#  'derive_testnet',
#  'gate_io',
#  'bing_x',
#  'ndax',
#  'ndax_testnet',
#  'okx',
#  'btc_markets',
#  'hyperliquid',
#  'hyperliquid_testnet',
#  'coinbase_advanced_trade',
#  'injective_v2',
#  'foxbit']

# %%
await client.connectors.get_trading_rules("kraken")
# Out:
# {'0G-EUR': {'min_order_size': 2.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  '0G-USD': {'min_order_size': 2.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  '1INCH-EUR': {'min_order_size': 11.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  '1INCH-USD': {'min_order_size': 11.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  '2Z-EUR': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  '2Z-USD': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AAVE-ETH': {'min_order_size': 0.015,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'AAVE-EUR': {'min_order_size': 0.015,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AAVE-GBP': {'min_order_size': 0.015,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'GBP',
#   'sell_order_collateral_token': 'GBP'},
#  'AAVE-USD': {'min_order_size': 0.015,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AAVE-BTC': {'min_order_size': 0.015,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'AB-EUR': {'min_order_size': 600.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AB-USD': {'min_order_size': 600.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ACA-EUR': {'min_order_size': 40.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ACA-USD': {'min_order_size': 40.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ACH-EUR': {'min_order_size': 130.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ACH-USD': {'min_order_size': 130.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ACT-EUR': {'min_order_size': 100.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ACT-USD': {'min_order_size': 100.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ACX-EUR': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ACX-USD': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ADA-AUD': {'min_order_size': 4.4,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'AUD',
#   'sell_order_collateral_token': 'AUD'},
#  'ADA-ETH': {'min_order_size': 4.4,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'ADA-EUR': {'min_order_size': 4.4,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ADA-GBP': {'min_order_size': 4.4,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'GBP',
#   'sell_order_collateral_token': 'GBP'},
#  'ADA-USD': {'min_order_size': 4.4,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ADA-USDC': {'min_order_size': 4.4,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'ADA-USDT': {'min_order_size': 4.4,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'ADA-BTC': {'min_order_size': 4.4,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'ADX-EUR': {'min_order_size': 22.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ADX-USD': {'min_order_size': 22.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AERO-EUR': {'min_order_size': 5.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AERO-USD': {'min_order_size': 5.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'A-EUR': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AEVO-EUR': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AEVO-USD': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AGLD-EUR': {'min_order_size': 1.8,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AGLD-USD': {'min_order_size': 1.8,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AI16Z-EUR': {'min_order_size': 55.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AI16Z-USD': {'min_order_size': 55.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AI16Z-USDC': {'min_order_size': 55.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'AI16Z-USDT': {'min_order_size': 55.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'AI3-EUR': {'min_order_size': 17.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AI3-USD': {'min_order_size': 17.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AIN-USD': {'min_order_size': 40.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AIO-EUR': {'min_order_size': 30.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AIO-USD': {'min_order_size': 30.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AIOZ-EUR': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AIOZ-USD': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AIR-EUR': {'min_order_size': 300.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AIR-USD': {'min_order_size': 300.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AIXBT-EUR': {'min_order_size': 20.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AIXBT-USD': {'min_order_size': 20.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AKE-EUR': {'min_order_size': 3400.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AKE-USD': {'min_order_size': 3400.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AKT-EUR': {'min_order_size': 1.2,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'AKT-USD': {'min_order_size': 1.2,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ALCH-EUR': {'min_order_size': 25.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ALCH-USD': {'min_order_size': 25.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ALCX-EUR': {'min_order_size': 0.15,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ALCX-USD': {'min_order_size': 0.15,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ALGO-ETH': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'ALGO-EUR': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ALGO-GBP': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'GBP',
#   'sell_order_collateral_token': 'GBP'},
#  'ALGO-USD': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ALGO-USDC': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'ALGO-USDT': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'ALGO-BTC': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-09,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'ALICE-EUR': {'min_order_size': 3.2,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ALICE-USD': {'min_order_size': 3.2,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ALKIMI-EUR': {'min_order_size': 50.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ALKIMI-USD': {'min_order_size': 50.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ALLO-EUR': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ALLO-USD': {'min_order_size': 10.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ALPHA-EUR': {'min_order_size': 50.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ALPHA-USD': {'min_order_size': 50.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ALT-EUR': {'min_order_size': 30.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ALTHEA-EUR': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ALTHEA-USD': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ALT-USD': {'min_order_size': 30.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ANIME-EUR': {'min_order_size': 50.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ANIME-USD': {'min_order_size': 50.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ANKR-EUR': {'min_order_size': 120.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ANKR-USD': {'min_order_size': 120.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ANKR-BTC': {'min_order_size': 120.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-10,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'ANLOG-EUR': {'min_order_size': 1000.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ANLOG-USD': {'min_order_size': 1000.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ANON-EUR': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ANON-USD': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'APE-EUR': {'min_order_size': 3.3,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'APENFT-EUR': {'min_order_size': 10000000.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-10,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'APENFT-USD': {'min_order_size': 10000000.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-10,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'APE-USD': {'min_order_size': 3.3,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'APE-USDC': {'min_order_size': 3.3,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'APE-USDT': {'min_order_size': 3.3,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'API3-EUR': {'min_order_size': 2.25,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'API3-USD': {'min_order_size': 2.25,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'APR-EUR': {'min_order_size': 25.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'APR-USD': {'min_order_size': 25.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'APT-EUR': {'min_order_size': 0.4,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'APT-USD': {'min_order_size': 0.4,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'APU-EUR': {'min_order_size': 35000.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'APU-USD': {'min_order_size': 35000.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ARB-EUR': {'min_order_size': 5.2,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ARB-USD': {'min_order_size': 5.2,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ARC-EUR': {'min_order_size': 250.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ARC-USD': {'min_order_size': 250.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AR-EUR': {'min_order_size': 0.25,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ARKM-EUR': {'min_order_size': 2.4,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ARKM-USD': {'min_order_size': 2.4,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ARPA-EUR': {'min_order_size': 90.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ARPA-USD': {'min_order_size': 90.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ART-EUR': {'min_order_size': 545.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ART-USD': {'min_order_size': 545.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'AR-USD': {'min_order_size': 0.25,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'ASRR-EUR': {'min_order_size': 15.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
# ...
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SCRT-EUR': {'min_order_size': 6.8,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SCRT-USD': {'min_order_size': 6.8,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'SC-USD': {'min_order_size': 650.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'SC-BTC': {'min_order_size': 650.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-10,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'SDN-EUR': {'min_order_size': 30.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SDN-USD': {'min_order_size': 30.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'SEI-EUR': {'min_order_size': 7.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SEI-USD': {'min_order_size': 7.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'S-EUR': {'min_order_size': 6.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SGB-EUR': {'min_order_size': 300.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SGB-USD': {'min_order_size': 300.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'SHIB-EUR': {'min_order_size': 160000.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SHIB-USD': {'min_order_size': 160000.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'SHIB-USDC': {'min_order_size': 160000.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'SHIB-USDT': {'min_order_size': 160000.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'SHX-EUR': {'min_order_size': 380.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SHX-USD': {'min_order_size': 380.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'SIDEKICK-EUR': {'min_order_size': 40.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SIDEKICK-USD': {'min_order_size': 40.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'SIDEKICK-USDT': {'min_order_size': 40.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'SIGMA-EUR': {'min_order_size': 100.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SIGMA-USD': {'min_order_size': 100.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'SKY-EUR': {'min_order_size': 65.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SKY-USD': {'min_order_size': 65.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'SLAY-EUR': {'min_order_size': 200.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SLAY-USD': {'min_order_size': 200.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'SNEK-EUR': {'min_order_size': 1375.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SNEK-USD': {'min_order_size': 1375.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'SNX-EUR': {'min_order_size': 1.5,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SNX-USD': {'min_order_size': 1.5,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'SNX-BTC': {'min_order_size': 1.5,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'SOGNI-EUR': {'min_order_size': 1100.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SOGNI-USD': {'min_order_size': 1100.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USD',
#   'sell_order_collateral_token': 'USD'},
#  'SOL-AUD': {'min_order_size': 0.02,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'AUD',
#   'sell_order_collateral_token': 'AUD'},
#  'SOL-CAD': {'min_order_size': 0.02,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'CAD',
#   'sell_order_collateral_token': 'CAD'},
#  'SOL-ETH': {'min_order_size': 0.02,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'SOL-EUR': {'min_order_size': 0.02,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'SOL-EURC': {'min_order_size': 0.02,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-08,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EURC',
#   'sell_order_collateral_token': 'EURC'},
#  ...}
